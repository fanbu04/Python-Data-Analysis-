# %% [markdown]
# Fan Bu
# MSIS Gold

# %% [markdown]
# # HW 1
# For this assignment, you will pick out the dataset that you are going to use for your rfinal project, and apply some of the skills that we learned today in class.
#
# Fill in this Jupyter Notebook, and turn it into Canvas. You may submit either a .ipynb file or a PDF file.
#
# ## Part 1: Find your dataset
# 1. Read [this article](https://www.umuc.edu/current-students/learning-resources/writing-center/writing-resources/evaluating-sources.cfm) on selecting reliable resources.
# 2. Select a dataset and list the URL below.
#     - https://catalog.data.gov/dataset/air-quality-measures-on-the-national-environmental-health-tracking-network
# 3. Describe why you think the dataset is from a credible source.
#     - Collected by a governmnt agency (Centers for Disease Control and Prevention)
#     - Time-series data on air quality from 1999 to 2013 from about 4,000 monitoring stations in the US
# 4. Come up with 5 questions that you might be able to ask from the dataset.
#     - The trend on air quality from 1999-2013
#     - Did the 2008 finanacial crisis have any impacts on air quality?
#     - Which state has the best/worst airqaulity throughout the period?
#     - Which county has the best/worst airqaulity throughout the period?
#     - Which monitoring station has the best/worst airqaulity throughout the period?

# %% [markdown]
# ## Part 2: Pandas Practice
# 1. Download the [adult income dataset](https://archive.ics.uci.edu/ml/machine-learning-databases/adult/adult.data)
# 2. Read up on the dataset [here](https://archive.ics.uci.edu/ml/datasets/adult)
# 3. Create a function to read the downloaded file into pandas
# 4. Take a look at the first 10 lines of the file
# 5. Add the following column names: ["age", "workclass", "fnlwgt", "education", "education_num", \
#                     "marital-status", "occupation", "relationship", "race", "sex", \
#                     "capital_gain", "capital_loss", "hours_per_week", "native_country", "income"]
# 6. Count the number of people in the dataset older over the age of 30 with a bachelor's degree
# 7. For two points, let me know what questions or feedback you would like on this assignment.

# %%
import pandas as pd
adult_path = "./adult.csv"
adult = pd.read_csv(adult_path, sep=",", header=None)
adult.head(10)
# Out:
#    0                  1       2           3   4                       5   \
# 0  39          State-gov   77516   Bachelors  13           Never-married
# 1  50   Self-emp-not-inc   83311   Bachelors  13      Married-civ-spouse
# 2  38            Private  215646     HS-grad   9                Divorced
# 3  53            Private  234721        11th   7      Married-civ-spouse
# 4  28            Private  338409   Bachelors  13      Married-civ-spouse
# 5  37            Private  284582     Masters  14      Married-civ-spouse
# 6  49            Private  160187         9th   5   Married-spouse-absent
# 7  52   Self-emp-not-inc  209642     HS-grad   9      Married-civ-spouse
# 8  31            Private   45781     Masters  14           Never-married
# 9  42            Private  159449   Bachelors  13      Married-civ-spouse
#
#                    6               7       8        9      10  11  12  \
# 0        Adm-clerical   Not-in-family   White     Male   2174   0  40
# ...

# %%
# add column names 
adult.columns =["age", "workclass", "fnlwgt", "education", "education_num", \
             "marital-status", "occupation", "relationship", "race", "sex", \
             "capital_gain", "capital_loss", "hours_per_week", "native_country", "income"]
adult.head(10)
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
# 5   37            Private  284582     Masters             14
# 6   49            Private  160187         9th              5
# 7   52   Self-emp-not-inc  209642     HS-grad              9
# 8   31            Private   45781     Masters             14
# 9   42            Private  159449   Bachelors             13
#
#            marital-status          occupation    relationship    race  \
# 0           Never-married        Adm-clerical   Not-in-family   White
# 1      Married-civ-spouse     Exec-managerial         Husband   White
# 2                Divorced   Handlers-cleaners   Not-in-family   White
# ...

# %%
# Count the number of people in the dataset older over the age of 30 with a bachelor's degree

# %%
adult["education"]=adult["education"].str.strip()

# %%
adult[adult["age"] > 30].count()
len(adult[adult["age"] > 30])
# Out:
# 21989

# %%
adult[adult["education"]=="Bachelors"].count()
len(adult[adult["education"]=="Bachelors"])
# Out:
# 5355

# %%
len(adult[(adult["age"] > 30)&(adult["education"]=="Bachelors")])
# Out:
# 3796

# %% [markdown]
# Questions and feedback:
# 1. I understand that we need to know the python basics that we learned from bootcamp, but only a few of us use python everyday. In that case, a bit more detailed explanation would be helpful.
# 2. Learning how to connect to a database was very useful, but it took a bit researching since I have a mac
# 3. Looking into different data sets was quite fun, it's more esaier to find reliable sources than I expected.
